# %% [markdown]
# # Exploratory Analysis
#
# This notebook loads the generated CSV outputs and gives a starting point for thesis-style analysis.

# %%
from pathlib import Path
import pandas as pd

root = Path('..')
results = pd.read_csv(root / 'results' / 'tables' / 'rng_battery_results.csv')
summary = pd.read_csv(root / 'results' / 'tables' / 'rng_battery_summary.csv')
summary

# %%
results.pivot(index='generator', columns='test', values='p_value').round(4)

# %%
results.loc[~results['passed'], ['generator', 'test', 'p_value']]
